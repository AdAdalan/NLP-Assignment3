# %% [markdown]
# <a href="https://colab.research.google.com/github/AdAdalan/NLP-Assignment3/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/AdAdalan/NLP-Assignment3.git
# %cd /content/NLP-Assignment3
# !ls
# Out:
# /content
# Cloning into 'NLP-Assignment3'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# Receiving objects: 100% (14/14), 6.29 KiB | 6.29 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# remote: Total 14 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# /content/NLP-Assignment3
# notebooks  outputs  src

# %%
# %cd /content/NLP-Assignment3
# !ls -la
# Out:
# /content/NLP-Assignment3
# total 32
# drwxr-xr-x 6 root root 4096 May  6 07:20 .
# drwxr-xr-x 1 root root 4096 May  6 07:20 ..
# drwxr-xr-x 8 root root 4096 May  6 07:20 .git
# -rw-r--r-- 1 root root 4754 May  6 07:20 .gitignore
# drwxr-xr-x 2 root root 4096 May  6 07:20 notebooks
# drwxr-xr-x 2 root root 4096 May  6 07:20 outputs
# drwxr-xr-x 2 root root 4096 May  6 07:20 src
