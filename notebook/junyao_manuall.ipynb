# %% [markdown]
# <a href="https://colab.research.google.com/github/AdAdalan/NLP-Assignment3/blob/main/notebook/junyao_manuall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %cd /content

if not os.path.exists("/content/NLP-Assignment3"):
  # !git clone https://github.com/AdAdalan/NLP-Assignment3.git
else:
  print("Repo already exists.")

# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
from pathlib import Path
DATA_DIR = Path("/content/drive/MyDrive/NLP ASS3/data")
# Out:
# /content
# Cloning into 'NLP-Assignment3'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 43 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 80.97 KiB | 4.26 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_10755/647691625.py in <cell line: 0>()
#      10 # 1. Mount Google Drive
#      11 from google.colab import drive
# ---> 12 drive.mount('/content/drive')
#      13 from pathlib import Path
#      14 DATA_DIR = Path("/content/drive/MyDrive/NLP ASS3/data")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
# ...
